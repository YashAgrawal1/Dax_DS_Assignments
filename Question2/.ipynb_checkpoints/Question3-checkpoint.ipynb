# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Resultant_CSV.csv")

# %%
type(df)
df.head()
# Out:
#          id  gender       age  hypertension  heart_disease ever_married  \
# 0  0.123214    Male  0.816895           0.0            1.0          Yes
# 1  0.708205  Female  0.743652           0.0            0.0          Yes
# 2  0.426015    Male  0.975586           0.0            1.0          Yes
# 3  0.824928  Female  0.597168           0.0            0.0          Yes
# 4  0.021929  Female  0.963379           1.0            0.0          Yes
#
#        work_type Residence_type  avg_glucose_level       bmi   smoking_status  \
# 0        Private          Urban           0.801265  0.301260  formerly smoked
# 1  Self-employed          Rural           0.679023  0.212981     never smoked
# 2        Private          Rural           0.234512  0.254296     never smoked
# 3        Private          Urban           0.536008  0.276060           smokes
# 4  Self-employed          Rural           0.549349  0.156930     never smoked
#
#    stroke bmi_category age_group glucose_level_category  bmiCategory ageGroup
# 0     1.0  Underweight     Young                    Low  Underweight    Young
# 1     1.0  Underweight     Young                    Low  Underweight    Young
# 2     1.0  Underweight     Young                    Low  Underweight    Young
# 3     1.0  Underweight     Young                    Low  Underweight    Young
# 4     1.0  Underweight     Young                    Low  Underweight    Young

# %%
X = df.drop(columns=['stroke']).values
y = df['stroke'].values

# %%
from sklearn.model_selection import train_test_split
#80-20 train and test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#75-25 Train was again split to make Train and Validation in ratio of 75-25
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 0.25,random_state=0)
